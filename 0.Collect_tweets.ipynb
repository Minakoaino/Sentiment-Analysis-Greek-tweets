# %%
import tweepy
# from tweepy.streaming.StreamListener import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import datetime
import csv
import pandas as pd

# %%
#not used for tweepy latest versions
# consumer_key = 'zRLze0lH2AKxY1bkVqpXfuhDZ'
# consumer_secret = 'hAbqGAiTjwvTVBdUX0MMdl7Eqcb5eQPPY5jwx4SkGj07I4hGaD'
# access_token = '1397618616653209602-3LUD2QVsxS5xjznEcTQJ6545G2lUko'
# access_token_secret = 'DALjzoSMrU71FoULD4VOYN46yCtl9c1xsKghGtQGPvNxa'

# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# auth.set_access_token(access_token, access_token_secret)
# api = tweepy.API(auth)

# %%
class MyStream(tweepy.Stream):
    def on_status(self,status):
        if hasattr(status, "retweeted_status"):
            try:
                current_status = str(status.retweeted_status.extended_tweet["full_text"])
                current_status = current_status.replace('\n', ' ').replace('\r', '')
                print(current_status)
                
            except AttributeError:
                current_status = str(status.retweeted_status.text)
                current_status = current_status.replace('\n', ' ').replace('\r', '')
                print(current_status)
        
        else:
            try:
                current_status = str(status.extended_tweet["full_text"])
                current_status = current_status.replace('\n', ' ').replace('\r', '')
                print(current_status)
            
            except AttributeError:
                current_status = str(status.text)
                current_status = current_status.replace('\n', ' ').replace('\r', '')
                print('Gathering tweets for hashtag - ', current_status)


                           
            csvw.writerow([status.id,
                           status.user.screen_name,
                           # created_at is a datetime object, converting to just grab the month/day/year
                           status.created_at.strftime('%m/%d/%y'),
                           status.favorited,
                           status.user.followers_count,
                           status.source,
                           status.user.location,
                           current_status])
            
    
    def on_request_error(self,status_code):
        if status_code == 420:
            print('You have been rate-limited for making too many requests')
            return False

# %%
if __name__ == '__main__':

    # This handles Twitter authetification and the connection to Twitter Streaming API
    #auth = OAuthHandler("zRLze0lH2AKxY1bkVqpXfuhDZ", "hAbqGAiTjwvTVBdUX0MMdl7Eqcb5eQPPY5jwx4SkGj07I4hGaD")
    #auth.set_access_token("1397618616653209602-3LUD2QVsxS5xjznEcTQJ6545G2lUko", "DALjzoSMrU71FoULD4VOYN46yCtl9c1xsKghGtQGPvNxa")
    csvw = csv.writer(open("data.csv", "a"))
    csvw.writerow(['twitter_id', 'name', 'created_at', 'is_retweet',
                   'followers_count', 'source', 'region', 'text'])
    stream = MyStream("zRLze0lH2AKxY1bkVqpXfuhDZ", "hAbqGAiTjwvTVBdUX0MMdl7Eqcb5eQPPY5jwx4SkGj07I4hGaD",
                      "1397618616653209602-3LUD2QVsxS5xjznEcTQJ6545G2lUko", "DALjzoSMrU71FoULD4VOYN46yCtl9c1xsKghGtQGPvNxa")
    stream.filter(languages=["el"],track=['εμβολιο','εμβόλιο', 'εμβολιασμος', 'αντιεμβολιαστες', 'αντιεμβολιαστές', '#ανεμβολιαστοι'])    # Filter based on listed items
# Out:
# @elanianovaorion @nikolastelos Αν κόψεις τα παραισθησιογόνα θα μείνει χώρος και για το εμβόλιο και αργότερα χάπι Covid.  Έχετε γίνει όλοι «ειδικοί» στα εμβόλια και έχετε πληροφόρηση από το… υπερπέραν ή καμμιά καφετζού. Αν κόψουν τη νοσηλεία για Covid σε μη εμβολιασμένους ίσως καταλάβουν τις συνέπειες
# 1. Εμβόλιο  2. Μάσκα (Ν95 ή χειρουργική) 3. Αερισμός εσωτερικών χώρων   Αν όλοι -ΟΛΟΙ- ακολουθούσαμε αυτά τα τρία απλά βήματα με αυτή αυτή σειρά σημασίας, η πανδημία θα είχε τεθεί υπό έλεγχο.
# 1/ Θυμάστε τη φαρμακοποιό Ειρήνη Μουμούρη, που βγήκε στον Ευαγγελάτο και έλεγε ότι σε κάποιους κάνουν το εμβόλιο και σε κάποιους κάνουν placebo, γι’ αυτό δεν έχουμε παρενέργειες;  Eίναι υποψήφια για το Σωματείο του Νοσοκομείου, με την παράταξη που πρόσκειται στο ΣΥΡΙΖΑ!  Thread. https://t.co/wOBIv1ftke
# Τίποτα πιο Ελλάδα από το εμβολιαστικό κέντρο Περιστερίου, που στην είσοδο ρωτάνε: Για εμβόλιο ή για εκλογές ΚΙΝΑΛ;
# Θα το ξαναγραψω... Αυτο που τελικα ΟΛΟΙ οι αρνητες , αντιεμβολιαστες, ψεκασμενοι βρισκουν πρωτο τραπεζι πιστα και τελικα την γλυτωνουν, εχει αρχισει και με κανει πολυ κακο ανθρωπο #τραγκας #πετρακος #ντροπη #εμβόλιο #αντιεμβολιαστες #κορωνοιος #ανεμβολιαστοι #αρνητες
# 1. Εμβόλιο  2. Μάσκα (Ν95 ή χειρουργική) 3. Αερισμός εσωτερικών χώρων   Αν όλοι -ΟΛΟΙ- ακολουθούσαμε αυτά τα τρία απλά βήματα με αυτή αυτή σειρά σημασίας, η πανδημία θα είχε τεθεί υπό έλεγχο.
# 1/ Θυμάστε τη φαρμακοποιό Ειρήνη Μουμούρη, που βγήκε στον Ευαγγελάτο και έλεγε ότι σε κάποιους κάνουν το εμβόλιο και σε κάποιους κάνουν placebo, γι’ αυτό δεν έχουμε παρενέργειες;  Eίναι υποψήφια για το Σωματείο του Νοσοκομείου, με την παράταξη που πρόσκειται στο ΣΥΡΙΖΑ!  Thread. https://t.co/wOBIv1ftke
# Τίποτα πιο Ελλάδα από το εμβολιαστικό κέντρο Περιστερίου, που στην είσοδο ρωτάνε: Για εμβόλιο ή για εκλογές ΚΙΝΑΛ;
# Gathering tweets for hashtag -  @zneraida Βρε εσείς, δεν θα κάνουμε εμβολιο κι ας λέτε...
# Gathering tweets for hashtag -  Το αφήνω εδώ στην άκρη, για μελέτη
# Εσείς που ρωτάτε πνευματικό για το #εμβολιο,  ρωτήστε τον και τι έχει το πλυντήριο ρούχων μου και ξεκινάει  πλύσιμο αλλά σταματάει μετά το 1ο λεπτό. Νερό δινει κανονικα και δουλεύει και η στράγγιση.  Indesit 7125, ευλογείτε.
# Αντιεμβολιαστές εισβάλουν σε χριστουγεννιάτικη αγορά που ζητούσε πιστοποιητικό εμβολιασμού ή αρνητικό τεστ στο Λουξεμβούργο. Στο Λουξεμβούργο.
# Έχω καλέσει φίλους λόγο εορτής δεν με απασχολεί αν ειναι #εμβολιασμένοι #ανεμβολιαστοι #ψέκια κτλ για μενα παραμένουν φίλοι μου. Ξέρεις τι ειναι να κλαίει μια ανεμβολιαστη φίλη στο τηλέφωνο ότα  της λές είσαι ευπρόσδεκτη σπίτι μου ενώ την εχουν φτύσει όλοι; αγάπη παιδιά μόνο.
# Μια χαρά Δεκέμβρης "μύρισε". Οι πόλεις είναι στολισμένες με φωτάκια, δέντρα κτλ. Το "All I want for Christmas is you" ακούγεται σε κάθε γωνιά. Οι εμπορικοί δρόμοι έχουν προσφορές, κόσμο που βολτάρει ή/και ψωνίζει. Κάνε μπάνιο, εμβόλιο ή ράπιντ και βγες απ' το λαγούμι σου σύντροφε
# Elenleon @Elenleon4 ΠΑΡΕ ΝΑ ΕΧΕΙΣ ΟΠΑΔΕ ΤΟΥ ΑΛΕΞΗ ΤΙ ΕΙΧΕ ΠΕΙ..... ΚΑΙ ΤΙ ΕΚΑΝΕ......ΕΙΝΑΙ ΚΑΙ ΑΥΤΟ ΣΑΝ ΤΟ ΟΧΙ..... ΠΟΥ ΤΟ ΕΚΑΝΕ ΝΑΙ https://t.co/nHa04O0m8d
# Η κατάσταση εκτροχιάστηκε απ’όταν η πολιτική μπλέχτηκε με την ιατρική. Είναι απαράδεκτο να λαμβάνονται αποφάσεις υγείας από πολιτικά πρόσωπα, και ένα χρήσιμο εμβόλιο να δίνεται όχι για την υγεία, αλλά για την ελευθερία, η οποία είναι ένα αδιαπραγμάτευτο δικαίωμα #εμβολιασμος
# Φαντάζεστε να μας πουν να βαράμε το εμβόλιο στην πούτσα; ερε γέλια που θα ρίξουμε
# Gathering tweets for hashtag -  Εμβόλιο Pfizer: Στις 13 Δεκεμβρίου στην Ελλάδα για παιδιά 5-11 ετών https://t.co/axhnSywcsI
# Gathering tweets for hashtag -  Εσάς παιδιά σπάσανε τα νεύρα σας μιλώντας με τους αντιεμβολιαστές γονείς σας πρωί πρωί ή είμαι ο τυχερός του τουίτερ?
# 1. Εμβόλιο  2. Μάσκα (Ν95 ή χειρουργική) 3. Αερισμός εσωτερικών χώρων   Αν όλοι -ΟΛΟΙ- ακολουθούσαμε αυτά τα τρία απλά βήματα με αυτή αυτή σειρά σημασίας, η πανδημία θα είχε τεθεί υπό έλεγχο.
# Δλδ υπάρχουν άνθρωποι οι οποίοι αν δεν ήταν Κυβέρνηση η ΝΔ θα έκαναν το εμβόλιο ενώ τώρα δεν το κάνουν για να "τιμωρήσουν" τον Μητσοτάκη? #εμβολιασμος  #ανεμβολιαστοι
# 1/ Θυμάστε τη φαρμακοποιό Ειρήνη Μουμούρη, που βγήκε στον Ευαγγελάτο και έλεγε ότι σε κάποιους κάνουν το εμβόλιο και σε κάποιους κάνουν placebo, γι’ αυτό δεν έχουμε παρενέργειες;  Eίναι υποψήφια για το Σωματείο του Νοσοκομείου, με την παράταξη που πρόσκειται στο ΣΥΡΙΖΑ!  Thread. https://t.co/wOBIv1ftke
# Εσάς παιδιά σπάσανε τα νεύρα σας μιλώντας με τους αντιεμβολιαστές γονείς σας πρωί πρωί ή είμαι ο τυχερός του τουίτερ?
# Αυτοί που σέρνονται απ'τη μύτη είναι όσοι πάνε να εμβολιαστουν χωρίς λόγο,ενώ τους είπαν ότι δεν τους προσφέρει τίποτα.Ξέρετε μπορείτε να μπείτε στη ΜΕΘ κ εσεις,ενώ κάνετε 1 εμβόλιο με κίνδυνο σοβαρή παρενέργεια.Δεν αποφασίζουμε με βάση τον #πετρακος αλλά με βάση τη λογική.Εσείς;
# Τι σημασια εχει εντος εκτος ΜΕΘ? Για #κυβερνηση_Μητσοτακη φαινεται λεει δεν εχει #κορονοιος #κρουσματα #ομικρον #εμβολιασμος #3η_δοση https://t.co/RVr4zw7pYr
# Διαβάζω για την 14χρονη που πέθανε στη Λαμία λόγω κορονοιου και στα σχόλια βλέπεις τα ψεκια να χτυπιούνται για το #Εμβολιο (ενώ ήταν ανεμβολιαστη) και κανείς τους να μην καταλαβαίνει την ζημιά που της προκάλεσε ο ιός, ώστε να καταλήξει. Είστε ανεκδιήγητοι πλέον. Δεν αντεχεστε
# Τι σημασια εχει εντος εκτος ΜΕΘ? Για #κυβερνηση_Μητσοτακη φαινεται λεει δεν εχει #κορονοιος #κρουσματα #ομικρον #εμβολιασμος #3η_δοση https://t.co/RVr4zw7pYr
# Έκανα και εγώ την αναμνηστική δόση.  Το εμβόλιο είναι η μόνη λύση για να πάρουμε πίσω τις ζωές μας.  Η επιστήμη και η λογική θα κερδίσουν!  #σηκώνουμε_μανίκια #ελευθερια https://t.co/DpwmLatmXH
# Έχω καλέσει φίλους λόγο εορτής δεν με απασχολεί αν ειναι #εμβολιασμένοι #ανεμβολιαστοι #ψέκια κτλ για μενα παραμένουν φίλοι μου. Ξέρεις τι ειναι να κλαίει μια ανεμβολιαστη φίλη στο τηλέφωνο ότα  της λές είσαι ευπρόσδεκτη σπίτι μου ενώ την εχουν φτύσει όλοι; αγάπη παιδιά μόνο.
# Διαβάζω για την 14χρονη που πέθανε στη Λαμία λόγω κορονοιου και στα σχόλια βλέπεις τα ψεκια να χτυπιούνται για το #Εμβολιο (ενώ ήταν ανεμβολιαστη) και κανείς τους να μην καταλαβαίνει την ζημιά που της προκάλεσε ο ιός, ώστε να καταλήξει. Είστε ανεκδιήγητοι πλέον. Δεν αντεχεστε
# εγω λεω να πουμε στη μαμα εταιρία pfizer που εβγαλε κ το βιαγκρα... αφου θα κανουμε εμβολιο καθε 6 μηνες ή χρόνο.... να βαζει κ λιγο βιαγκρα μεσα... να δεις για ποτε θα το κανουν ολοι...
# Gathering tweets for hashtag -  Αυτά είναι! #εμβολιασμενοι #ανεμβολιαστοι #Προστιμο_100 #Εμβολιο  https://t.co/1tJZSyKLSf
# Διαβάζω για την 14χρονη που πέθανε στη Λαμία λόγω κορονοιου και στα σχόλια βλέπεις τα ψεκια να χτυπιούνται για το #Εμβολιο (ενώ ήταν ανεμβολιαστη) και κανείς τους να μην καταλαβαίνει την ζημιά που της προκάλεσε ο ιός, ώστε να καταλήξει. Είστε ανεκδιήγητοι πλέον. Δεν αντεχεστε
# @ProdromosChris1 @ISOTITAunion @philenewscy @hadjipantela Αρα το εμβόλιο δεν το βάζεις όχι γιατί φοβάσαι ότι θα πεθάνεις και θα αφήσεις την οικογένεια σου χωρίς εισοδήματα , άρα γιατί το ανέφερες ως επιχείρημα;   Άρα ο λόγος που δεν βάζεις το εμβολιο Ποιος είναι;
# Εγώ πάντως θα περίμενα πιο δημοφιλές θέμα να ναι η σύλληψη του Αντιπροέδρου του Σ.Τ.Ε  απ'τις εκλογές στο ΚΙΝΑΛ. Αλλά μετά θυμήθηκα ότι μένω στην Ελλάδα και ήρθα στα ίδια μου. #εμβολιασμος #ΚΙΝΑΛ #Σταματη
# Gathering tweets for hashtag -  Και 3η και 4η και με Πασοκ / Κιναλ και με ΝΔ και με Συριζα #Εμβολιο #εμβολιασμενοι #ψεκια https://t.co/oUiFHSW9rV
# Τραγκας &amp; Πετρακος ποτέ δεν είπαν πως είναι αντιεμβολιαστές ! Απλά είπαν πως το εμβόλιο το έβγαλαν οι φαρμακευτικές για να οικονομήσουν, όλες οι κυβερνήσεις είναι στο κόλπο &amp; πως είναι καρκινογόνο.  Τι μυστήριοι είστε μερικοί..
# @lybejohn @theopoulara @mwro_almighty Ο HIV δεν είναι αυτοανοσο νόσημα. Είναι ιός που προκαλεί Σύνδρομο επίκτητης ανοσοανεπαρκειας. Δηλαδή επιτίθεται στα λεμφοκυτταρα και αποδυναμώνει το ανοσοποιητικο σου σύστημα. Ένας από τους λόγους που δεν έχουν φτιάξει ακόμη εμβόλιο είναι ότι μεταλλασεται πολύ συχνά.
# Δεν θέλει να κάνει εμβόλιο κάθε 3,6,9 μήνες ο Έλληνας, αλλά την τσιγαρουκλα 15 φορές τη μέρα την καπνίζει.  Disclaimer: ΔΕΝ ΘΑ ΚΑΝΟΥΜΕ ΚΑΘΕ 3, 6 ΜΗΝΕΣ ΕΜΒΟΛΙΟ, ΕΤΣΙ ΤΟ ΠΑ. (γιατί είστε και στοκοι)
# Εσάς παιδιά σπάσανε τα νεύρα σας μιλώντας με τους αντιεμβολιαστές γονείς σας πρωί πρωί ή είμαι ο τυχερός του τουίτερ?
# Εσάς παιδιά σπάσανε τα νεύρα σας μιλώντας με τους αντιεμβολιαστές γονείς σας πρωί πρωί ή είμαι ο τυχερός του τουίτερ?
# εκλεισα για εμβολιο ραντεβου στις 9 το βραδυ ελπιζω μονο μετα να βγαζουν και καμια μπυρα μη παει ξεροσφυρι
# Έκανα και εγώ την αναμνηστική δόση.  Το εμβόλιο είναι η μόνη λύση για να πάρουμε πίσω τις ζωές μας.  Η επιστήμη και η λογική θα κερδίσουν!  #σηκώνουμε_μανίκια #ελευθερια https://t.co/DpwmLatmXH
# Gathering tweets for hashtag -  Κορωνοϊός: Η προστασία των mRNA εμβολίων διαρκεί περισσότερο  #COVID19 #Εμβόλιο https://t.co/GZIR59mtk7
# Τίποτα πιο Ελλάδα από το εμβολιαστικό κέντρο Περιστερίου, που στην είσοδο ρωτάνε: Για εμβόλιο ή για εκλογές ΚΙΝΑΛ;
# Κάνατε καμιά κλινική εξέταση πριν κάνετε το #Εμβολιο ? ρ/τ παρακαλώ για την αλήθεια! #εμβολιασμος
# 1. Εμβόλιο  2. Μάσκα (Ν95 ή χειρουργική) 3. Αερισμός εσωτερικών χώρων   Αν όλοι -ΟΛΟΙ- ακολουθούσαμε αυτά τα τρία απλά βήματα με αυτή αυτή σειρά σημασίας, η πανδημία θα είχε τεθεί υπό έλεγχο.
# Εσάς παιδιά σπάσανε τα νεύρα σας μιλώντας με τους αντιεμβολιαστές γονείς σας πρωί πρωί ή είμαι ο τυχερός του τουίτερ?
# 1/ Θυμάστε τη φαρμακοποιό Ειρήνη Μουμούρη, που βγήκε στον Ευαγγελάτο και έλεγε ότι σε κάποιους κάνουν το εμβόλιο και σε κάποιους κάνουν placebo, γι’ αυτό δεν έχουμε παρενέργειες;  Eίναι υποψήφια για το Σωματείο του Νοσοκομείου, με την παράταξη που πρόσκειται στο ΣΥΡΙΖΑ!  Thread. https://t.co/wOBIv1ftke
# Gathering tweets for hashtag -  Έχω κάνει το εμβόλιο εδώ και τέσσερις ώρες και δεν έχω τίποτα ούτε λίγο πονοκέφαλο, μήπως μου βάλανε placebo;
# Έκανα και εγώ την αναμνηστική δόση.  Το εμβόλιο είναι η μόνη λύση για να πάρουμε πίσω τις ζωές μας.  Η επιστήμη και η λογική θα κερδίσουν!  #σηκώνουμε_μανίκια #ελευθερια https://t.co/DpwmLatmXH
# Διαβάζω για την 14χρονη που πέθανε στη Λαμία λόγω κορονοιου και στα σχόλια βλέπεις τα ψεκια να χτυπιούνται για το #Εμβολιο (ενώ ήταν ανεμβολιαστη) και κανείς τους να μην καταλαβαίνει την ζημιά που της προκάλεσε ο ιός, ώστε να καταλήξει. Είστε ανεκδιήγητοι πλέον. Δεν αντεχεστε
# Μάθαμε τελικά στο πρώτο ραντεβού για εμβόλιο ποιος πληρώνει;
# @bpapapanagiotou Κάτι σαν το μνημόνιο δηλαδή που έλεγε ότι θα το καταργήσει αφού πρώτα το «διαπραγματευτεί»!  Τις πρώτες ημέρες θα είναι προαιρετικό το εμβόλιο αν πάρει την εξουσία και αμέσως μετά θα επιβάλει υποχρεωτικούς εμβολιασμούς. Θα έχει πολύ «πλάκα» όταν τελικά συγκυβερνήσουν με την ΝΔ.
# 1/ Θυμάστε τη φαρμακοποιό Ειρήνη Μουμούρη, που βγήκε στον Ευαγγελάτο και έλεγε ότι σε κάποιους κάνουν το εμβόλιο και σε κάποιους κάνουν placebo, γι’ αυτό δεν έχουμε παρενέργειες;  Eίναι υποψήφια για το Σωματείο του Νοσοκομείου, με την παράταξη που πρόσκειται στο ΣΥΡΙΖΑ!  Thread. https://t.co/wOBIv1ftke
# Και αίφνης ένα δυνατό Τράγκα τρούγκα ακούστηκε στη ΜΕΘ του Σωτηρία... #αντιεμβολιαστες #ψεκια
# @greekwitch1984 Δεν βγάζω άκρη...έχω θυμό αυτή τη στιγμή. Γιατί παλεύω να τη πείσω από τη στιγμή που βγήκε το εμβόλιο και φτάνουμε στη πηγή για να μη πιούμε νερό τελικά.
# Gathering tweets for hashtag -  Και για ποιο λόγο κάνουμε ήδη την 3η δόση;
# 1. Εμβόλιο  2. Μάσκα (Ν95 ή χειρουργική) 3. Αερισμός εσωτερικών χώρων   Αν όλοι -ΟΛΟΙ- ακολουθούσαμε αυτά τα τρία απλά βήματα με αυτή αυτή σειρά σημασίας, η πανδημία θα είχε τεθεί υπό έλεγχο.
# Εσάς παιδιά σπάσανε τα νεύρα σας μιλώντας με τους αντιεμβολιαστές γονείς σας πρωί πρωί ή είμαι ο τυχερός του τουίτερ?
# 1. Εμβόλιο  2. Μάσκα (Ν95 ή χειρουργική) 3. Αερισμός εσωτερικών χώρων   Αν όλοι -ΟΛΟΙ- ακολουθούσαμε αυτά τα τρία απλά βήματα με αυτή αυτή σειρά σημασίας, η πανδημία θα είχε τεθεί υπό έλεγχο.
# Εσάς παιδιά σπάσανε τα νεύρα σας μιλώντας με τους αντιεμβολιαστές γονείς σας πρωί πρωί ή είμαι ο τυχερός του τουίτερ?
# Έχω κάνει το εμβόλιο εδώ και τέσσερις ώρες και δεν έχω τίποτα ούτε λίγο πονοκέφαλο, μήπως μου βάλανε placebo;
# @VersBarelin @Annanewsi @nikolastelos Ψάξε τα βίντεο υπάρχουν στο ίντερνετ ελεύθερα.. Να δεις από μόνος σου τι λένε..επισης δικαίωμα σου είναι το εμβόλιο και καλά κάνεις και του ζητάς.. Άλλο τοσο δικαίωμα μου είναι να μην το θέλω..γιατί είναι σε πειραματικό στάδιο και όπως είπες δεν ξέρουν τι τους γίνεται.
# Τραγκας &amp; Πετρακος ποτέ δεν είπαν πως είναι αντιεμβολιαστές ! Απλά είπαν πως το εμβόλιο το έβγαλαν οι φαρμακευτικές για να οικονομήσουν, όλες οι κυβερνήσεις είναι στο κόλπο &amp; πως είναι καρκινογόνο.  Τι μυστήριοι είστε μερικοί..
# Εσάς παιδιά σπάσανε τα νεύρα σας μιλώντας με τους αντιεμβολιαστές γονείς σας πρωί πρωί ή είμαι ο τυχερός του τουίτερ?
# Ειναι κι ο #πετρακος ρε παιδιά ακόμα στο παγκάκι και δεν ξέρουμε εδώ στο #σωτήρια τι ρυθμίσεις να βάλουμε στον αναπνευστήρα. #εμβολιασμός #Εμβολιο #κορωνοιος
# @SPIROSGANIAS στους 1130 που μπηκαν στις ΜΕΘ σε μια εβδομαδα οι 370 ηταν εμβολιασμενοι, οπως ο 50χρονος που ηταν εκτος 5 μερες αλλα ο αρνητης μητροπολιτης βρηκε ΜΕΘ σε λιγες ωρες, ρωτησε τους λοιπον γιατι οι μισες ΜΕΘ ειναι κλειστες κ αλλο η οργανωση κ αλλο ο εμβολιασμος καταλαβες στοκε?
# Λαμία: Νεκρή 14χρονη μαθήτρια που νοσούσε έχοντας ήπια συμπτώματα   ΥΠΟΧΡΕΩΤΙΚΟΣ ΜΑΖΙΚΟΣ ΕΜΒΟΛΙΑΣΜΟΣ ΠΑΝΤΟΥ ΧΘΕΣ...ΚΑΙ ΠΟΙΝΙΚΗ ΔΙΩΞΗ ΣΕ ΚΕΡΑΜΕΩΣ ΚΑΙ ΤΣΙΟΔΡΑ ΓΙΑ ΤΗΝ ΑΝΕΞΕΛΕΓΚΤΗ ΔΙΑΣΠΟΡΑ ΚΟΡΩΝΟΪΟΥ ΣΤΑ ΣΧΟΛΕΙΑ
# Μπραβο Κυριακο Μητσοτακη, εισαι ο πρωτος στο γνωστό σύμπαν που θα δημιουργησεις εμβολιασμενους αρνητες εμβολιων! #εμβολιασμος
# 1/ Θυμάστε τη φαρμακοποιό Ειρήνη Μουμούρη, που βγήκε στον Ευαγγελάτο και έλεγε ότι σε κάποιους κάνουν το εμβόλιο και σε κάποιους κάνουν placebo, γι’ αυτό δεν έχουμε παρενέργειες;  Eίναι υποψήφια για το Σωματείο του Νοσοκομείου, με την παράταξη που πρόσκειται στο ΣΥΡΙΖΑ!  Thread. https://t.co/wOBIv1ftke
# Gathering tweets for hashtag -  @afroditi_gr Μπορούν να κάνουν εμβολιο και να μην πληρώσουν. Τι,οχι;
# Τραγκας &amp; Πετρακος ποτέ δεν είπαν πως είναι αντιεμβολιαστές ! Απλά είπαν πως το εμβόλιο το έβγαλαν οι φαρμακευτικές για να οικονομήσουν, όλες οι κυβερνήσεις είναι στο κόλπο &amp; πως είναι καρκινογόνο.  Τι μυστήριοι είστε μερικοί..
# Έχω κάνει το εμβόλιο εδώ και τέσσερις ώρες και δεν έχω τίποτα ούτε λίγο πονοκέφαλο, μήπως μου βάλανε placebo;
# Αντιεμβολιαστές εισβάλουν σε χριστουγεννιάτικη αγορά που ζητούσε πιστοποιητικό εμβολιασμού ή αρνητικό τεστ στο Λουξεμβούργο. Στο Λουξεμβούργο.
# Επειδή θέλετε να είμαστε με την επιστήμη, δείξτε μου έναν άνθρωπο που για κάποια χρόνια έκανε ανά 3μηνες το εμβόλιο και δεν έχει καμία παρενέργεια.
# @osr55blog @ProdromosChris1 @philenewscy @hadjipantela Δεν το βάζω γιατί το έβαλα ήδη!  Στα παιδιά συμφωνώ με τον ΠΟΥ.   Στους ενήλικες πάλι συμφωνώ γιατί έβαλα εμβόλιο &amp;κάνω &amp; τέστ και τηρώ και τα μέτρα.  Και θύμισα &amp;του λογιστή τις απόψεις του ΠΟΥ για την 3η δόση.  Δεν θα συμφωνήσω όμως ποτέ να γίνει κανείς ισόβιος αυτοκράτορας!
# Παντως ειμαι συγκλονισμένος με την ανθρωπια των ψεκεμβολιασμενους σε οτι αφορα την νοσηλεια του Γ. Τραγκα...Θελει η πουτανα να κρυφτει και η χαρα δεν την αφηνει! Σημ. ειμαι εμβολιασμενος, αλλα ντροπη σας #εμβολιασμος #πετρακος #Εμβολιο #Ομικρον
# Βλέπω θέλετε πιο σκληροπυρηνικό εμβόλιο για 3η δόση οι ΑστραΖενεκανς που κλαίγατε με 37.5 κ πόνο στα κοκκαλάκια σας στην πρώτη δόση ΑΓΥΡΤΕΣ.
# Gathering tweets for hashtag -  Έβαλα μέσο και έκανα την 3η δόση μια μέρα νωρίτερα #Εμβολιο
# Gathering tweets for hashtag -  Μήπως λέω μηπως αντί για επιπλέον ΜΕΘ να φτιαχτούν περισσότερες ψυχιατρικές κλινικές;  #ψεκια #Εμβολιο #εμβολιασμενοι #πετρακος
# Συγκλονιστική αυτή η ανάρτηση. Διαβάστέ την και εμβολιαστείτε είναι κρίμα ο φόβος για το εμβόλιο να παίρνει από κοντά μας τόσους άξιους ανθρώπους που θα μπορούσαν να είχαν σωθεί!  https://t.co/DDaQ176Fn8
# 1. Εμβόλιο  2. Μάσκα (Ν95 ή χειρουργική) 3. Αερισμός εσωτερικών χώρων   Αν όλοι -ΟΛΟΙ- ακολουθούσαμε αυτά τα τρία απλά βήματα με αυτή αυτή σειρά σημασίας, η πανδημία θα είχε τεθεί υπό έλεγχο.
# @ta_ta_Van @yialeleli @FauxAda Δεν έχει νόημα στις φαρμακευτικές αλλεργίες μπορείς να πάθεις αλλεργικό σοκ, πολύ αργότερα. Έχω πάθει αλλεργία σε εμβόλιο την επόμενη μέρα...
# Διαβάζω για την 14χρονη που πέθανε στη Λαμία λόγω κορονοιου και στα σχόλια βλέπεις τα ψεκια να χτυπιούνται για το #Εμβολιο (ενώ ήταν ανεμβολιαστη) και κανείς τους να μην καταλαβαίνει την ζημιά που της προκάλεσε ο ιός, ώστε να καταλήξει. Είστε ανεκδιήγητοι πλέον. Δεν αντεχεστε
# 1. Εμβόλιο  2. Μάσκα (Ν95 ή χειρουργική) 3. Αερισμός εσωτερικών χώρων   Αν όλοι -ΟΛΟΙ- ακολουθούσαμε αυτά τα τρία απλά βήματα με αυτή αυτή σειρά σημασίας, η πανδημία θα είχε τεθεί υπό έλεγχο.
# Elenleon @Elenleon4 ΠΑΡΕ ΝΑ ΕΧΕΙΣ ΟΠΑΔΕ ΤΟΥ ΑΛΕΞΗ ΤΙ ΕΙΧΕ ΠΕΙ..... ΚΑΙ ΤΙ ΕΚΑΝΕ......ΕΙΝΑΙ ΚΑΙ ΑΥΤΟ ΣΑΝ ΤΟ ΟΧΙ..... ΠΟΥ ΤΟ ΕΚΑΝΕ ΝΑΙ https://t.co/nHa04O0m8d
# 🙄Τα εμβόλια δεν τα κάνουμε γιατί το λέει ο Μητσοτάκης, τα κάνουμε για εμάς κ,τους δικούς μας ανθρώπους. Όσοι ζήσαμε τον εφιάλτη στα σπίτια μας στο πρώτο κύμα ξέρουμε, οι υπόλοιποι ας κάνουν ό,τι τους φωτίσει..το μυαλό τους γιατί ο Θεός δεν έχει καμια σχέση με αυτό. #εμβολιασμος
# Μια χαρά Δεκέμβρης "μύρισε". Οι πόλεις είναι στολισμένες με φωτάκια, δέντρα κτλ. Το "All I want for Christmas is you" ακούγεται σε κάθε γωνιά. Οι εμπορικοί δρόμοι έχουν προσφορές, κόσμο που βολτάρει ή/και ψωνίζει. Κάνε μπάνιο, εμβόλιο ή ράπιντ και βγες απ' το λαγούμι σου σύντροφε
# 1/ Θυμάστε τη φαρμακοποιό Ειρήνη Μουμούρη, που βγήκε στον Ευαγγελάτο και έλεγε ότι σε κάποιους κάνουν το εμβόλιο και σε κάποιους κάνουν placebo, γι’ αυτό δεν έχουμε παρενέργειες;  Eίναι υποψήφια για το Σωματείο του Νοσοκομείου, με την παράταξη που πρόσκειται στο ΣΥΡΙΖΑ!  Thread. https://t.co/wOBIv1ftke
# Gathering tweets for hashtag -  #Εμβολιο  Ρε, εδώ ούτε οι καταθέσεις είναι εγγυημένες !
# Αυτο  #ψεκια #αντιεμβολιαστες #ανεμβολιαστοι #ανεμβολιαστους #antivaxxers #εμβολιο #εμβολια #εμβολιασμος #κρουσματα #ΜΕΘ #κορωνοιος #κορονοιος #ομικρον https://t.co/9pIVupQZbG
# Το δώρο της επιστήμης μας, στο δώρο της ζωής μου. Μπαμπάς και Μαριαλένα cool! #εμβόλιο https://t.co/s7e9NKf3Ed
# Συγκλονιστική αυτή η ανάρτηση. Διαβάστέ την και εμβολιαστείτε είναι κρίμα ο φόβος για το εμβόλιο να παίρνει από κοντά μας τόσους άξιους ανθρώπους που θα μπορούσαν να είχαν σωθεί!  https://t.co/DDaQ176Fn8
# @VersBarelin @Annanewsi @nikolastelos Με υποθέσεις φίλε μου σε κλείνουν σπίτι για 50 κρούσματα.. Και τώρα σου λένε η μόνη λύση είναι το εμβόλιο το οποίο όμως και πάλι δεν σε προστατεύει στην τελική.. Αλλά αυτούς πρέπει να ακούμε μόνο..
# Στις #ΗΠΑ το Ανώτατο δικαστήριο διέταξε τον #FDA δημοσιεύσει όλες  τις πληροφορίες σχετικά με το εμβόλιο της #Pfizer .Η πρώτη παρτίδα εγγράφων επιβεβαίωσε πάνω από 1.200 θανάτους στις ΗΠΑ από τα εμβόλια μέσα στις πρώτες 90 ημέρες.#Μητσοτακη_καθαρμα
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7370/3270243613.py in <module>
#       9     stream = MyStream("zRLze0lH2AKxY1bkVqpXfuhDZ", "hAbqGAiTjwvTVBdUX0MMdl7Eqcb5eQPPY5jwx4SkGj07I4hGaD",
#      10                       "1397618616653209602-3LUD2QVsxS5xjznEcTQJ6545G2lUko", "DALjzoSMrU71FoULD4VOYN46yCtl9c1xsKghGtQGPvNxa")
# ---> 11     stream.filter(languages=["el"],track=['εμβολιο','εμβόλιο', 'εμβολιασμος', 'αντιεμβολιαστες', 'αντιεμβολιαστές', '#ανεμβολιαστοι'])    # Filter based on listed items
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in filter(self, follow, track, locations, filter_level, languages, stall_warnings, threaded)
#     268                                           body=body)
#     269         else:
# --> 270             self._connect(method, endpoint, headers=headers, body=body)
#     271
#     272     def sample(self, *, languages=None, stall_warnings=False, threaded=False):
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _connect(self, method, endpoint, params, headers, body)
#     127                                 break
#     128
# --> 129                             for line in resp.iter_lines(
#     130                                 chunk_size=self.chunk_size
#     131                             ):
#
# /usr/lib/python3/dist-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     792         pending = None
#     793
# --> 794         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     795
#     796             if pending is not None:
#
# /usr/lib/python3/dist-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# /usr/lib/python3/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     558         """
#     559         if self.chunked and self.supports_chunked_reads():
# --> 560             for line in self.read_chunked(amt, decode_content=decode_content):
#     561                 yield line
#     562         else:
#
# /usr/lib/python3/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     750
#     751             while True:
# --> 752                 self._update_chunk_length()
#     753                 if self.chunk_left == 0:
#     754                     break
#
# /usr/lib/python3/dist-packages/urllib3/response.py in _update_chunk_length(self)
#     680         if self.chunk_left is not None:
#     681             return
# --> 682         line = self._fp.fp.readline()
#     683         line = line.split(b";", 1)[0]
#     684         try:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
